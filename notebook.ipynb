# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

from matplotlib import pyplot as plt
from sklearn.datasets import make_regression

# %%
# Import the data
file = Path('Resources/myopia.csv')
df = pd.read_csv(file)
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
target = df['MYOPIC']
features = df.drop('MYOPIC', axis=1)
features.head
# Out:
# <bound method NDFrame.head of      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# ...

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(features)

# %%
# Initialize PCA model
pca = PCA(n_components=0.9)

# Get two principal components for the iris data.
myopia_pca = pca.fit_transform(df_scaled)

# %%
myopia_pca.shape
# Out:
# (618, 10)

# %%
# Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.21177355, 0.15659716, 0.08688023, 0.08301762, 0.07584858,
#        0.06997878, 0.06486986, 0.06377808, 0.05393666, 0.05205566])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.9187361702915188

# %%
tsne = TSNE(learning_rate="auto", init="pca", n_iter= 250)
tsne_features=tsne.fit_transform(myopia_pca)
# Out:
# c:\Users\basse\anaconda3\envs\mlenv\lib\site-packages\sklearn\manifold\_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
tsne_features.shape
# Out:
# (618, 2)

# %%
plt.scatter(tsne_features[:,0], tsne_features[:,1])
plt.show()

# %%
plt.scatter(tsne_features[:,0], tsne_features[:,1], c=target)
plt.show()

# %%
cluster_myopia_pca = pd.DataFrame(
    data=myopia_pca, columns=['m1', 'm2','m3','m4','m5','m6','m7','m8','m9','m10'])
cluster_myopia_pca.head()
# Out:
#          m1        m2        m3        m4        m5        m6        m7  \
# 0  0.535503  1.145004 -1.385019  0.116006 -3.226691 -1.928459 -1.958892
# 1 -0.624706 -1.575786 -0.794253  1.156287  0.292256  0.349060 -0.455206
# 2 -0.933479 -0.717076  0.820150 -1.547638  0.173941  0.272783  0.025821
# 3  0.106354  1.192475 -0.024441  1.507469 -2.356836 -0.023139  0.236418
# 4 -0.388503 -2.839655 -0.229767 -0.622510  0.271458 -0.928956  0.537900
#
#          m8        m9       m10
# 0 -1.922997  0.026753  0.178144
# 1  0.285332  0.689683 -0.557031
# 2 -0.030817 -0.431499  0.013336
# 3 -1.717109 -1.230785 -0.703400
# 4 -1.301787  0.279007  0.631183

# %%
inertia = []
k = list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(cluster_myopia_pca)
    inertia.append(km.inertia_)

# Define a DataFrame to plot the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# c:\Users\basse\anaconda3\envs\mlenv\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   "KMeans is known to have a memory leak on Windows "

# %%
def get_clusters(k, data):
    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Train the model
    model.fit(data)

    # Predict clusters
    predictions = model.predict(data)

    # Create return DataFrame with predicted clusters
    data["class"] = model.labels_

    return data

# %%
clusters = get_clusters(3, cluster_myopia_pca)
clusters
# Out:
#            m1        m2        m3        m4        m5        m6        m7  \
# 0    0.535503  1.145004 -1.385019  0.116006 -3.226691 -1.928459 -1.958892
# 1   -0.624706 -1.575786 -0.794253  1.156287  0.292256  0.349060 -0.455206
# 2   -0.933479 -0.717076  0.820150 -1.547638  0.173941  0.272783  0.025821
# 3    0.106354  1.192475 -0.024441  1.507469 -2.356836 -0.023139  0.236418
# 4   -0.388503 -2.839655 -0.229767 -0.622510  0.271458 -0.928956  0.537900
# ..        ...       ...       ...       ...       ...       ...       ...
# 613 -0.237547  1.146547 -1.546054 -0.248834  2.326683 -0.202403  0.084104
# 614 -0.649011 -1.796952 -0.823592  0.564878  0.134282  0.348639 -0.174354
# 615 -0.890082 -2.308005  0.268102  0.262770  0.231606  0.566061 -0.328287
# 616 -1.124000  0.451890  0.001659 -0.847089 -0.143347 -0.414353 -0.448120
# 617 -0.691534 -0.737046 -1.052900 -0.502772 -0.882590 -0.231183 -1.447594
#
#            m8        m9       m10  class
# ...

# %%
def show_clusters(cluster_myopia_pca):
    plt.scatter(cluster_myopia_pca['m1'], cluster_myopia_pca['m2'], c=cluster_myopia_pca['class'])
    plt.title('Clusters')
    plt.xlabel('m1')
    plt.ylabel('m2')
    plt.show()

# %%
show_clusters(clusters)

# %% [markdown]
# Recommendation:
#
# Based on the results PCA, t-SNE, and K-means modeling, it appears that the patients can be categorized into three clusters.
