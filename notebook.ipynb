# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

from matplotlib import pyplot as plt
from sklearn.datasets import make_regression

# %%
# Import the data
file = Path('Resources/myopia.csv')
df = pd.read_csv(file)
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
X = df.drop('MYOPIC', axis=1)
y = df['MYOPIC']
df.head(10)
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# 5    6  1.744  22.139999  3.224  3.556  15.36       10       6       2
# 6    6  0.683  22.330000  3.186  3.654  15.49       12       7       2
# 7    6  1.272  22.389999  3.732  3.584  15.08       12       0       0
# 8    7  1.396  22.620001  3.464  3.408  15.74        4       0       3
# 9    6  0.972  22.740000  3.504  3.696  15.54       30       5       1
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# ...

# %% [markdown]
# 1) Standardize your dataset so that columns that contain larger values do not influence the outcome more than columns with smaller values.
# 2) Perform dimensionality reduction with PCA. How did the number of the features change?
# 3) perform cluster analysis with K-means- elbow plot. use loop to determine the intertia for each k between 1 through 10
# 4) make recommendation
